# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
img=cv2.imread("/content/downloaded.jpg",cv2.IMREAD_COLOR)
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# -1

# %%
bigger=cv2.resize(img,(1000,1000))
cv2_imshow(bigger)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
# -1

# %%
half =cv2.resize(img,(0,0),fx=0.5,fy=0.5)
cv2_imshow(half)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=150x84>
# -1

# %%
stretch_near = cv2.resize(img, (100, 100), interpolation=cv2.INTER_NEAREST)
cv2_imshow(stretch_near)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>
# -1

# %%
import matplotlib.pyplot as plt
Titles=["Original","Half","Bigger","Strech Near"]
images=[img,half,bigger,stretch_near]
for i in range(4):
  plt.subplot(2,3,i+1)
  plt.title(Titles[i])
  plt.imshow(images[i])
#cv2.waitKey(0)

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/downloaded.jpg")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# -1

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/downloaded.jpg")
cv2_imshow(image)
cv2.waitKey(0)

#Gaussian Blur
Gaussian=cv2.GaussianBlur(image,(7,7),0)
cv2_imshow(Gaussian)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>
# -1

# %%
#Median Blur
median=cv2.medianBlur(image,5)
cv2_imshow(median)
cv2.waitKey(0)
#Bilateral Blur
bilateral=cv2.bilateralFilter(image,9,75,75)
cv2_imshow(bilateral)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Display the blurred image
#import matplotlib.pyplot as plt
#plt.imshow(blurred_image, cmap='gray')
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
image = cv2.imread('/content/downloaded.jpg')

# Convert the image to grayscale
grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to the grayscale image
blurred_image = cv2.GaussianBlur(grayscale_image, (5, 5), 0)

# Display the blurred image
import matplotlib.pyplot as plt
plt.imshow(blurred_image, cmap='gray')
plt.show()

# %%
img=cv2.imread('/content/downloaded.jpg')
edge=cv2.Canny(img,100,150)
cv2_imshow(edge)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=300x168>
# -1

# %%
(rows,cols)=img.shape[:2]
print(rows,cols)
M=cv2.getRotationMatrix2D((cols/2,rows/2),45,1)
res=cv2.warpAffine(img,M,(200,200))
cv2_imshow(res)
cv2.waitKey(0)
# Out:
# 168 300
# <PIL.Image.Image image mode=RGB size=200x200>
# -1

# %%
#import opencv
import cv2
alg='haarcascade_frontalface_default.xml'
cascade=cv2.CascadeClassifier(alg)
cam=cv2.VideoCapture(0)
while True:
  _,img=cam.read()
  grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  face=cascade.detectMultiScale(grayImg)
  for (x,y,w,h) in face:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
  cv2.imshow("FaceDetect",img)
  key=cv2.waitKey(1)
  if key==81 or key==113:
    break
cv2.destroyAllWindows()
cam.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-66-2fe49fc77683> in <cell line: 6>()
#       6 while True:
#       7   _,img=cam.read()
# ----> 8   grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       9
#      10   face=cascade.detectMultiScale(grayImg)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2

# %%
cam_port=0
cam=cv2.VideoCapture(cam_port)
result,image=cam.read()
if result:
  cv2.imshow("pst",image)
  #cv2.imwrite("pst",image)
  cv2.waitKey(0)
  cv2.destroyWindow("pst")
else:
  print("No image")
# Out:
# No image
